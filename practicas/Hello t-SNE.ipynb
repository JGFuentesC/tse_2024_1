# %% [markdown]
# ## Dependencias

# %%
import pandas as pd 
import cufflinks as cf
from sklearn.datasets import make_blobs

from sklearn.preprocessing import MinMaxScaler
from sklearn.manifold import TSNE

cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.25.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## Datos sintéticos (espacio original $\mathcal{X}$)

# %%
X,y = make_blobs(100,6,centers=6,cluster_std=0.1)

# %%
X= pd.DataFrame(X,columns=[f'x{i+1}' for i in range(6)])

# %%
X.head()
# Out:
#          x1        x2        x3        x4        x5        x6
# 0 -1.963431 -8.469857  9.430890  4.823868  1.616483 -0.291919
# 1 -0.752307  9.859769  7.202085 -7.950335  1.069579 -0.758559
# 2  0.103010  6.414171 -5.762670 -4.068507 -1.162052 -4.633696
# 3 -1.962807 -8.550038  9.440406  4.608357  1.657684 -0.369891
# 4  9.946199  2.936617  5.267201  4.059494  4.003102 -1.426372

# %% [markdown]
# ## Cambio de espacio con t-SNE $\mathcal{X}_t$

# %%
tsne = TSNE(n_components=3, n_jobs=-1,perplexity=20)

Xt = pd.DataFrame(tsne.fit_transform(X), columns=[f'x{i+1}' for i in range(3)])

# %%
Xt.iplot(kind='scatter3d',x='x1',y='x2',z='x3',mode='markers',size=10,color='purple')
# Out:
# <div>                            <div id="38f77e92-2cb2-42a8-956a-468f42a359aa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...
